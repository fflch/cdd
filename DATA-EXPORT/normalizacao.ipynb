# %%
import pandas as pd

dados = pd.read_csv('cdd.csv', dtype=pd.StringDtype())

# %%
# quando: bla VER ble
# bla: remissiva
# ble: assunto

### vamos criar uma coluna nova chamada remissiva

# %%
import re
dados['titulo'] = dados.titulo.str.replace(' v. ', ' VER ')
dados[['First','Last']] = dados.titulo.str.split(" VER ",expand=True)
dados.head(10)
# Out:
#                                               titulo               cdd  \
# 0  Angela da Foligno (1248 – 1309) VER Ângela de ...              <NA>
# 1            Gilbert Porreta VER Gilbert de Poitiers              <NA>
# 2  Philosophische Texte. Studienausgabe  (Jürgen ...  193.96 H114pt v.
# 3  Pseudo-Denys l'Aréopagite  VER Dionísio, o Aer...              <NA>
# 4                          Abade de Locédio (d.1214)              <NA>
# 5              Abailard, Pierre VER ABERLARDO, Pedro              <NA>
# 6                     Abalos Sísmicos VER TERREMOTOS              <NA>
# 7                Abélard, Pierre VER ABELARDO, Pedro              <NA>
# 8  ABELARDO, PEDRO, filósofo e teólogo escolástic...             189.4
# 9                      Abelardus VER ABELARDO, Pedro              <NA>
#
#   Criado_por                              Observação     Tipo  \
# 0       <NA>                                    <NA>     <NA>
# 1       <NA>                                    <NA>     <NA>
# 2    2508542  Existe em português: 193.96 H114ptP v.     <NA>
# 3    2508542                                    <NA>     <NA>
# 4       <NA>                                    <NA>    Autor
# 5       <NA>                                    <NA>    Autor
# 6      fflch                                    <NA>  Assunto
# 7      fflch                                    <NA>    Autor
# 8       <NA>                              189.4 A139    Autor
# 9      fflch                                    <NA>    Autor
#
#   Enviado para SIBI Normalizado Remissiva  \
# 0              <NA>        <NA>      <NA>
# 1              <NA>        <NA>      <NA>
# 2              <NA>        <NA>      <NA>
# 3              <NA>        <NA>      <NA>
# 4              <NA>        <NA>      <NA>
# 5              <NA>        <NA>      <NA>
# 6              <NA>        <NA>      <NA>
# 7              <NA>        <NA>      <NA>
# 8              <NA>        <NA>      <NA>
# 9              <NA>        <NA>      <NA>
#
#                                                First  \
# 0                    Angela da Foligno (1248 – 1309)
# 1                                    Gilbert Porreta
# 2  Philosophische Texte. Studienausgabe  (Jürgen ...
# 3                         Pseudo-Denys l'Aréopagite
# 4                          Abade de Locédio (d.1214)
# 5                                   Abailard, Pierre
# 6                                    Abalos Sísmicos
# 7                                    Abélard, Pierre
# 8  ABELARDO, PEDRO, filósofo e teólogo escolástic...
# 9                                          Abelardus
#
#                                       Last
# 0                        Ângela de Foligno
# 1                      Gilbert de Poitiers
# 2                                     <NA>
# 3  Dionísio, o Aeropagita, Pseudo-Dionísio
# 4                                     <NA>
# 5                         ABERLARDO, Pedro
# 6                               TERREMOTOS
# 7                          ABELARDO, Pedro
# 8                                     <NA>
# 9                          ABELARDO, Pedro

# %%
for index, row in dados.iterrows():
    if isinstance(row['First'], str) and isinstance(row['Last'], str):
        dados.at[index,'titulo'] = row['Last']
        dados.at[index,'Remissiva'] = row['First']
dados.head(10)
# Out:
#                                               titulo               cdd  \
# 0                                  Ângela de Foligno              <NA>
# 1                                Gilbert de Poitiers              <NA>
# 2  Philosophische Texte. Studienausgabe  (Jürgen ...  193.96 H114pt v.
# 3            Dionísio, o Aeropagita, Pseudo-Dionísio              <NA>
# 4                          Abade de Locédio (d.1214)              <NA>
# 5                                   ABERLARDO, Pedro              <NA>
# 6                                         TERREMOTOS              <NA>
# 7                                    ABELARDO, Pedro              <NA>
# 8  ABELARDO, PEDRO, filósofo e teólogo escolástic...             189.4
# 9                                    ABELARDO, Pedro              <NA>
#
#   Criado_por                              Observação     Tipo  \
# 0       <NA>                                    <NA>     <NA>
# 1       <NA>                                    <NA>     <NA>
# 2    2508542  Existe em português: 193.96 H114ptP v.     <NA>
# 3    2508542                                    <NA>     <NA>
# 4       <NA>                                    <NA>    Autor
# 5       <NA>                                    <NA>    Autor
# 6      fflch                                    <NA>  Assunto
# 7      fflch                                    <NA>    Autor
# 8       <NA>                              189.4 A139    Autor
# 9      fflch                                    <NA>    Autor
#
#   Enviado para SIBI Normalizado                        Remissiva  \
# 0              <NA>        <NA>  Angela da Foligno (1248 – 1309)
# 1              <NA>        <NA>                  Gilbert Porreta
# 2              <NA>        <NA>                             <NA>
# 3              <NA>        <NA>       Pseudo-Denys l'Aréopagite
# 4              <NA>        <NA>                             <NA>
# 5              <NA>        <NA>                 Abailard, Pierre
# 6              <NA>        <NA>                  Abalos Sísmicos
# 7              <NA>        <NA>                  Abélard, Pierre
# 8              <NA>        <NA>                             <NA>
# 9              <NA>        <NA>                        Abelardus
#
#                                                First  \
# 0                    Angela da Foligno (1248 – 1309)
# 1                                    Gilbert Porreta
# 2  Philosophische Texte. Studienausgabe  (Jürgen ...
# 3                         Pseudo-Denys l'Aréopagite
# 4                          Abade de Locédio (d.1214)
# 5                                   Abailard, Pierre
# 6                                    Abalos Sísmicos
# 7                                    Abélard, Pierre
# 8  ABELARDO, PEDRO, filósofo e teólogo escolástic...
# 9                                          Abelardus
#
#                                       Last
# 0                        Ângela de Foligno
# 1                      Gilbert de Poitiers
# 2                                     <NA>
# 3  Dionísio, o Aeropagita, Pseudo-Dionísio
# 4                                     <NA>
# 5                         ABERLARDO, Pedro
# 6                               TERREMOTOS
# 7                          ABELARDO, Pedro
# 8                                     <NA>
# 9                          ABELARDO, Pedro

# %%
dados['Tipo'].unique()
# Out:
# <StringArray>
# [<NA>, 'Autor', 'Assunto', 'Coleção']
# Length: 4, dtype: string

# %%
dados['Enviado para SIBI'].unique()
# Out:
# <StringArray>
# [<NA>, 'Não enviado', 'Enviado para SIBI']
# Length: 3, dtype: string

# %%
dados['Normalizado'].unique()
# Out:
# <StringArray>
# [<NA>, 'Não normalizado', 'Normalizado']
# Length: 3, dtype: string

# %%
dados['cdd'].unique()
# Out:
# <StringArray>
# [               <NA>,  '193.96 H114pt v.',             '189.4',
#             '297.38', '301.426363.46 (*)',           '304.667',
#        '296.16 A155',             '181.3',          '869.9137',
#              '321.6',
#  ...
#            '916.894',     '294.3294.3927',           '916.891',
#       '199.4973 Z82',            '382.78',            '551.62',
#              '307.3',            '307.32',    '615.2591.9 (*)',
#                '295']
# Length: 2732, dtype: string

# %%
dados = dados.drop('First', axis=1)
dados = dados.drop('Last', axis=1)
dados.head(10)
# Out:
#                                               titulo               cdd  \
# 0                                  Ângela de Foligno              <NA>
# 1                                Gilbert de Poitiers              <NA>
# 2  Philosophische Texte. Studienausgabe  (Jürgen ...  193.96 H114pt v.
# 3            Dionísio, o Aeropagita, Pseudo-Dionísio              <NA>
# 4                          Abade de Locédio (d.1214)              <NA>
# 5                                   ABERLARDO, Pedro              <NA>
# 6                                         TERREMOTOS              <NA>
# 7                                    ABELARDO, Pedro              <NA>
# 8  ABELARDO, PEDRO, filósofo e teólogo escolástic...             189.4
# 9                                    ABELARDO, Pedro              <NA>
#
#   Criado_por                              Observação     Tipo  \
# 0       <NA>                                    <NA>     <NA>
# 1       <NA>                                    <NA>     <NA>
# 2    2508542  Existe em português: 193.96 H114ptP v.     <NA>
# 3    2508542                                    <NA>     <NA>
# 4       <NA>                                    <NA>    Autor
# 5       <NA>                                    <NA>    Autor
# 6      fflch                                    <NA>  Assunto
# 7      fflch                                    <NA>    Autor
# 8       <NA>                              189.4 A139    Autor
# 9      fflch                                    <NA>    Autor
#
#   Enviado para SIBI Normalizado                        Remissiva
# 0              <NA>        <NA>  Angela da Foligno (1248 – 1309)
# 1              <NA>        <NA>                  Gilbert Porreta
# 2              <NA>        <NA>                             <NA>
# 3              <NA>        <NA>       Pseudo-Denys l'Aréopagite
# 4              <NA>        <NA>                             <NA>
# 5              <NA>        <NA>                 Abailard, Pierre
# 6              <NA>        <NA>                  Abalos Sísmicos
# 7              <NA>        <NA>                  Abélard, Pierre
# 8              <NA>        <NA>                             <NA>
# 9              <NA>        <NA>                        Abelardus

# %%
dados.to_csv('cdd_normalizado_1.csv', index=False)
