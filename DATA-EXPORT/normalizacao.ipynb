# %%
import pandas as pd

dados = pd.read_csv('cdd.csv')
dados
# Out:
#                                                  titulo               cdd  \
# 0     Angela da Foligno (1248 – 1309) VER Ângela de ...               NaN
# 1               Gilbert Porreta VER Gilbert de Poitiers               NaN
# 2     Philosophische Texte. Studienausgabe  (Jürgen ...  193.96 H114pt v.
# 3     Pseudo-Denys l'Aréopagite  VER Dionísio, o Aer...               NaN
# 4                             Abade de Locédio (d.1214)               NaN
# ...                                                 ...               ...
# 4192                                   ZONEAMENTO RURAL            307.72
# 4193                                  ZONEAMENTO URBANO            307.32
# 4194                                       ZOOGEOGRAFIA    615.2591.9 (*)
# 4195                                       ZOROASTRISMO               295
# 4196                 |a Studies in church history |v 30               NaN
#
#      Criado_por                              Observação     Tipo  \
# ...

# %%
# quando: bla VER ble
# bla: remissiva
# ble: assunto

### vamos criar uma coluna nova chamada remissiva
